# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 782

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a89061ec613c0d4c206e6cc8181409dd

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Parse out weather description 
        city_description = city_weather ["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mujiayingzi
# Processing Record 2 of Set 1 | pevek
# Processing Record 3 of Set 1 | geraldton
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | hemnes
# City not found. Skipping...
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | flin flon
# Processing Record 11 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 1 | ilulissat
# Processing Record 13 of Set 1 | yilan
# Processing Record 14 of Set 1 | morgan city
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | iqaluit
# Processing Record 20 of Set 1 | midland
# Processing Record 21 of Set 1 | tauramena
# Processing Record 22 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | kaitangata
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | saint-georges
# Processing Record 28 of Set 1 | hovd
# Processing Record 29 of Set 1 | jaisalmer
# Processing Record 30 of Set 1 | boone
# Processing Record 31 of Set 1 | saint-pierre
# Processing Record 32 of Set 1 | kaspiysk
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | leon
# Processing Record 35 of Set 1 | clyde river
# Processing Record 36 of Set 1 | zheleznodorozhnyy
# Processing Record 37 of Set 1 | lagos
# Processing Record 38 of Set 1 | taltal
# Processing Record 39 of Set 1 | venkatagiri
# Processing Record 40 of Set 1 | toamasina
# Processing Record 41 of Set 1 | georgetown
# Processing Record 42 of Set 1 | lebu
# Processing Record 43 of Set 1 | emba
# Processing Record 44 of Set 1 | moree
# Processing Record 45 of Set 1 | arlit
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | jiwani
# Processing Record 48 of Set 1 | usinsk
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | huitzuco
# City not found. Skipping...
# Processing Record 1 of Set 2 | nkhotakota
# Processing Record 2 of Set 2 | puro
# Processing Record 3 of Set 2 | mangrol
# Processing Record 4 of Set 2 | coahuayana
# Processing Record 5 of Set 2 | taoudenni
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | nanortalik
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | soyo
# Processing Record 10 of Set 2 | baker city
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | dekalb
# Processing Record 13 of Set 2 | ayan
# Processing Record 14 of Set 2 | obihiro
# Processing Record 15 of Set 2 | luanda
# Processing Record 16 of Set 2 | bayan
# Processing Record 17 of Set 2 | lamu
# Processing Record 18 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 2 | xining
# Processing Record 20 of Set 2 | plettenberg bay
# Processing Record 21 of Set 2 | rosarito
# Processing Record 22 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 2 | castro
# Processing Record 26 of Set 2 | rehoboth
# Processing Record 27 of Set 2 | boa vista
# Processing Record 28 of Set 2 | panama city
# Processing Record 29 of Set 2 | chuy
# Processing Record 30 of Set 2 | shirokiy
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | aqtobe
# Processing Record 33 of Set 2 | sao jose da coroa grande
# Processing Record 34 of Set 2 | port jervis
# Processing Record 35 of Set 2 | swan river
# Processing Record 36 of Set 2 | charlestown
# Processing Record 37 of Set 2 | caravelas
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | abu zabad
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | puerto leguizamo
# Processing Record 42 of Set 2 | souillac
# Processing Record 43 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 44 of Set 2 | fallon
# Processing Record 45 of Set 2 | bambous virieux
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | manaure
# Processing Record 48 of Set 2 | jamestown
# Processing Record 49 of Set 2 | upernavik
# Processing Record 50 of Set 2 | krasnoselkup
# Processing Record 1 of Set 3 | krutikha
# Processing Record 2 of Set 3 | faya
# Processing Record 3 of Set 3 | touros
# Processing Record 4 of Set 3 | carnarvon
# Processing Record 5 of Set 3 | tasiilaq
# Processing Record 6 of Set 3 | dongli
# Processing Record 7 of Set 3 | airai
# Processing Record 8 of Set 3 | hobart
# Processing Record 9 of Set 3 | cidreira
# Processing Record 10 of Set 3 | vestmannaeyjar
# Processing Record 11 of Set 3 | maumere
# Processing Record 12 of Set 3 | bethel
# Processing Record 13 of Set 3 | basco
# Processing Record 14 of Set 3 | beringovskiy
# Processing Record 15 of Set 3 | beamsville
# Processing Record 16 of Set 3 | fukue
# Processing Record 17 of Set 3 | alofi
# Processing Record 18 of Set 3 | torphins
# Processing Record 19 of Set 3 | codrington
# Processing Record 20 of Set 3 | chara
# Processing Record 21 of Set 3 | la ronge
# Processing Record 22 of Set 3 | moerai
# Processing Record 23 of Set 3 | lompoc
# Processing Record 24 of Set 3 | umm lajj
# Processing Record 25 of Set 3 | poya
# Processing Record 26 of Set 3 | kapaa
# Processing Record 27 of Set 3 | port hardy
# Processing Record 28 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 3 | kodiak
# Processing Record 30 of Set 3 | shelburne
# Processing Record 31 of Set 3 | shingu
# Processing Record 32 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 3 | sistranda
# Processing Record 34 of Set 3 | cape town
# Processing Record 35 of Set 3 | vaini
# Processing Record 36 of Set 3 | turukhansk
# Processing Record 37 of Set 3 | kainan
# Processing Record 38 of Set 3 | vanimo
# Processing Record 39 of Set 3 | yichang
# Processing Record 40 of Set 3 | cabo san lucas
# Processing Record 41 of Set 3 | fairbanks
# Processing Record 42 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 43 of Set 3 | kavaratti
# Processing Record 44 of Set 3 | trinidad
# Processing Record 45 of Set 3 | srednekolymsk
# Processing Record 46 of Set 3 | lagoa vermelha
# Processing Record 47 of Set 3 | sao filipe
# Processing Record 48 of Set 3 | sault sainte marie
# Processing Record 49 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 3 | san patricio
# Processing Record 1 of Set 4 | mar del plata
# Processing Record 2 of Set 4 | yima
# Processing Record 3 of Set 4 | baruun-urt
# Processing Record 4 of Set 4 | marawi
# Processing Record 5 of Set 4 | saint-philippe
# Processing Record 6 of Set 4 | vizinga
# Processing Record 7 of Set 4 | talnakh
# Processing Record 8 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 4 | nipawin
# Processing Record 10 of Set 4 | klaksvik
# Processing Record 11 of Set 4 | ponta delgada
# Processing Record 12 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 4 | hasaki
# Processing Record 14 of Set 4 | kavieng
# Processing Record 15 of Set 4 | tiarei
# Processing Record 16 of Set 4 | svetlogorsk
# Processing Record 17 of Set 4 | pilar
# Processing Record 18 of Set 4 | sorland
# Processing Record 19 of Set 4 | erice
# Processing Record 20 of Set 4 | darhan
# Processing Record 21 of Set 4 | komsomolskiy
# Processing Record 22 of Set 4 | mirnyy
# Processing Record 23 of Set 4 | abalak
# Processing Record 24 of Set 4 | avera
# Processing Record 25 of Set 4 | iracoubo
# Processing Record 26 of Set 4 | narsaq
# Processing Record 27 of Set 4 | aden
# Processing Record 28 of Set 4 | zlatoust
# Processing Record 29 of Set 4 | san quintin
# Processing Record 30 of Set 4 | wajima
# Processing Record 31 of Set 4 | cherskiy
# Processing Record 32 of Set 4 | glazov
# Processing Record 33 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 4 | bandarbeyla
# Processing Record 35 of Set 4 | tessalit
# Processing Record 36 of Set 4 | leningradskiy
# Processing Record 37 of Set 4 | fomboni
# Processing Record 38 of Set 4 | poso
# Processing Record 39 of Set 4 | southbridge
# Processing Record 40 of Set 4 | diamantino
# Processing Record 41 of Set 4 | hobyo
# Processing Record 42 of Set 4 | qaqortoq
# Processing Record 43 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 4 | waipawa
# Processing Record 45 of Set 4 | nikolskoye
# Processing Record 46 of Set 4 | ranong
# Processing Record 47 of Set 4 | hami
# Processing Record 48 of Set 4 | akyab
# Processing Record 49 of Set 4 | berlevag
# Processing Record 50 of Set 4 | constitucion
# Processing Record 1 of Set 5 | kargasok
# Processing Record 2 of Set 5 | claremore
# Processing Record 3 of Set 5 | methoni
# Processing Record 4 of Set 5 | el buen pastor
# City not found. Skipping...
# Processing Record 5 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 6 of Set 5 | guozhen
# Processing Record 7 of Set 5 | paamiut
# Processing Record 8 of Set 5 | oberstdorf
# Processing Record 9 of Set 5 | bocanda
# Processing Record 10 of Set 5 | kuybyshevo
# Processing Record 11 of Set 5 | broken hill
# Processing Record 12 of Set 5 | hithadhoo
# Processing Record 13 of Set 5 | inirida
# Processing Record 14 of Set 5 | nanchang
# Processing Record 15 of Set 5 | danielskuil
# Processing Record 16 of Set 5 | goma
# Processing Record 17 of Set 5 | saint-joseph
# Processing Record 18 of Set 5 | lima
# Processing Record 19 of Set 5 | axim
# Processing Record 20 of Set 5 | te anau
# Processing Record 21 of Set 5 | oriximina
# Processing Record 22 of Set 5 | ancud
# Processing Record 23 of Set 5 | bathsheba
# Processing Record 24 of Set 5 | comodoro rivadavia
# Processing Record 25 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 5 | lorengau
# Processing Record 27 of Set 5 | flinders
# Processing Record 28 of Set 5 | tabou
# Processing Record 29 of Set 5 | marsh harbour
# Processing Record 30 of Set 5 | lagoa
# Processing Record 31 of Set 5 | westport
# Processing Record 32 of Set 5 | dikson
# Processing Record 33 of Set 5 | khunti
# Processing Record 34 of Set 5 | zhaodong
# Processing Record 35 of Set 5 | namatanai
# Processing Record 36 of Set 5 | conde
# Processing Record 37 of Set 5 | tezu
# Processing Record 38 of Set 5 | mahebourg
# Processing Record 39 of Set 5 | port keats
# Processing Record 40 of Set 5 | ixtapa
# Processing Record 41 of Set 5 | olafsvik
# Processing Record 42 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 43 of Set 5 | belaya gora
# Processing Record 44 of Set 5 | shemysheyka
# Processing Record 45 of Set 5 | cayenne
# Processing Record 46 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 5 | mao
# Processing Record 48 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 49 of Set 5 | tuatapere
# Processing Record 50 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 1 of Set 6 | yellowknife
# Processing Record 2 of Set 6 | solvychegodsk
# Processing Record 3 of Set 6 | rio grande
# Processing Record 4 of Set 6 | hervey bay
# Processing Record 5 of Set 6 | bandar-e anzali
# Processing Record 6 of Set 6 | alice springs
# Processing Record 7 of Set 6 | itaituba
# Processing Record 8 of Set 6 | grand gaube
# Processing Record 9 of Set 6 | peci
# Processing Record 10 of Set 6 | broome
# Processing Record 11 of Set 6 | victoria
# Processing Record 12 of Set 6 | mitsamiouli
# Processing Record 13 of Set 6 | otjiwarongo
# Processing Record 14 of Set 6 | kropotkin
# Processing Record 15 of Set 6 | meulaboh
# Processing Record 16 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 6 | sajanan
# Processing Record 18 of Set 6 | port blair
# Processing Record 19 of Set 6 | rameswaram
# Processing Record 20 of Set 6 | norman wells
# Processing Record 21 of Set 6 | wenling
# Processing Record 22 of Set 6 | rafai
# Processing Record 23 of Set 6 | avarua
# Processing Record 24 of Set 6 | deputatskiy
# Processing Record 25 of Set 6 | inhambane
# Processing Record 26 of Set 6 | yazoo city
# Processing Record 27 of Set 6 | mecca
# Processing Record 28 of Set 6 | kahului
# Processing Record 29 of Set 6 | borogontsy
# Processing Record 30 of Set 6 | chokurdakh
# Processing Record 31 of Set 6 | nantucket
# Processing Record 32 of Set 6 | uspenka
# Processing Record 33 of Set 6 | warburton
# Processing Record 34 of Set 6 | pavilosta
# Processing Record 35 of Set 6 | chuncheng
# Processing Record 36 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 6 | songjianghe
# Processing Record 38 of Set 6 | strathaven
# Processing Record 39 of Set 6 | borovoy
# Processing Record 40 of Set 6 | covington
# Processing Record 41 of Set 6 | arraial do cabo
# Processing Record 42 of Set 6 | biak
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | rio gallegos
# Processing Record 45 of Set 6 | knysna
# Processing Record 46 of Set 6 | chapais
# Processing Record 47 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 48 of Set 6 | katherine
# Processing Record 49 of Set 6 | faanui
# Processing Record 50 of Set 6 | tukrah
# Processing Record 1 of Set 7 | hamilton
# Processing Record 2 of Set 7 | cockburn town
# Processing Record 3 of Set 7 | pisco
# Processing Record 4 of Set 7 | onega
# Processing Record 5 of Set 7 | buraydah
# Processing Record 6 of Set 7 | sterling
# Processing Record 7 of Set 7 | zhigalovo
# Processing Record 8 of Set 7 | beaverlodge
# Processing Record 9 of Set 7 | sinnamary
# Processing Record 10 of Set 7 | east london
# Processing Record 11 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 7 | grindavik
# Processing Record 13 of Set 7 | longhua
# Processing Record 14 of Set 7 | luderitz
# Processing Record 15 of Set 7 | whitehorse
# Processing Record 16 of Set 7 | saint george
# Processing Record 17 of Set 7 | verkhoturye
# Processing Record 18 of Set 7 | tsumeb
# Processing Record 19 of Set 7 | osa
# Processing Record 20 of Set 7 | acarau
# Processing Record 21 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 22 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 7 | valente
# Processing Record 25 of Set 7 | abu samrah
# Processing Record 26 of Set 7 | marquette
# Processing Record 27 of Set 7 | saldanha
# Processing Record 28 of Set 7 | anadyr
# Processing Record 29 of Set 7 | kampot
# Processing Record 30 of Set 7 | tikamgarh
# Processing Record 31 of Set 7 | panzhihua
# Processing Record 32 of Set 7 | adrar
# Processing Record 33 of Set 7 | atar
# Processing Record 34 of Set 7 | os
# City not found. Skipping...
# Processing Record 35 of Set 7 | mayo
# Processing Record 36 of Set 7 | solenzo
# Processing Record 37 of Set 7 | zhuhai
# Processing Record 38 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 7 | vengurla
# Processing Record 40 of Set 7 | pacific grove
# Processing Record 41 of Set 7 | qui nhon
# Processing Record 42 of Set 7 | adre
# Processing Record 43 of Set 7 | wajir
# Processing Record 44 of Set 7 | lovozero
# Processing Record 45 of Set 7 | san-pedro
# Processing Record 46 of Set 7 | vostok
# Processing Record 47 of Set 7 | rincon
# Processing Record 48 of Set 7 | bairiki
# Processing Record 49 of Set 7 | newport
# Processing Record 50 of Set 7 | cabatuan
# Processing Record 1 of Set 8 | yarmouth
# Processing Record 2 of Set 8 | goderich
# Processing Record 3 of Set 8 | yook
# Processing Record 4 of Set 8 | thompson
# Processing Record 5 of Set 8 | provideniya
# Processing Record 6 of Set 8 | guerrero negro
# Processing Record 7 of Set 8 | lamar
# Processing Record 8 of Set 8 | fortuna
# Processing Record 9 of Set 8 | mount isa
# Processing Record 10 of Set 8 | itarema
# Processing Record 11 of Set 8 | mount gambier
# Processing Record 12 of Set 8 | kokopo
# Processing Record 13 of Set 8 | mulchen
# Processing Record 14 of Set 8 | fuerte olimpo
# Processing Record 15 of Set 8 | la tuque
# Processing Record 16 of Set 8 | leshukonskoye
# Processing Record 17 of Set 8 | inuvik
# Processing Record 18 of Set 8 | naze
# Processing Record 19 of Set 8 | verkhnevilyuysk
# Processing Record 20 of Set 8 | wattegama
# Processing Record 21 of Set 8 | novoanninskiy
# Processing Record 22 of Set 8 | belyy yar
# Processing Record 23 of Set 8 | bubaque
# Processing Record 24 of Set 8 | opuwo
# Processing Record 25 of Set 8 | remanso
# Processing Record 26 of Set 8 | port augusta
# Processing Record 27 of Set 8 | calabozo
# Processing Record 28 of Set 8 | katsuura
# Processing Record 29 of Set 8 | mahajanga
# Processing Record 30 of Set 8 | carballo
# Processing Record 31 of Set 8 | zhangjiakou
# Processing Record 32 of Set 8 | christchurch
# Processing Record 33 of Set 8 | safita
# Processing Record 34 of Set 8 | pulaski
# Processing Record 35 of Set 8 | honiara
# Processing Record 36 of Set 8 | laguna
# Processing Record 37 of Set 8 | dunedin
# Processing Record 38 of Set 8 | kamina
# Processing Record 39 of Set 8 | neiafu
# Processing Record 40 of Set 8 | sitka
# Processing Record 41 of Set 8 | zyryanka
# Processing Record 42 of Set 8 | sao sebastiao
# Processing Record 43 of Set 8 | katobu
# Processing Record 44 of Set 8 | pala
# Processing Record 45 of Set 8 | elko
# Processing Record 46 of Set 8 | sisimiut
# Processing Record 47 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 48 of Set 8 | tacana
# Processing Record 49 of Set 8 | san policarpo
# Processing Record 50 of Set 8 | perbaungan
# Processing Record 1 of Set 9 | harper
# Processing Record 2 of Set 9 | shimanovsk
# Processing Record 3 of Set 9 | bamiantong
# Processing Record 4 of Set 9 | isangel
# Processing Record 5 of Set 9 | fonte boa
# Processing Record 6 of Set 9 | derzhavinsk
# Processing Record 7 of Set 9 | necochea
# Processing Record 8 of Set 9 | amazar
# Processing Record 9 of Set 9 | torbay
# Processing Record 10 of Set 9 | belmonte
# Processing Record 11 of Set 9 | dubbo
# Processing Record 12 of Set 9 | bend
# Processing Record 13 of Set 9 | cheyenne
# Processing Record 14 of Set 9 | kampene
# Processing Record 15 of Set 9 | smithers
# Processing Record 16 of Set 9 | jahrom
# City not found. Skipping...
# Processing Record 17 of Set 9 | qiyang
# Processing Record 18 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 19 of Set 9 | krasnovishersk
# Processing Record 20 of Set 9 | majene
# Processing Record 21 of Set 9 | maceio
# Processing Record 22 of Set 9 | berdigestyakh
# Processing Record 23 of Set 9 | bengkulu
# Processing Record 24 of Set 9 | buchanan
# Processing Record 25 of Set 9 | tandil
# Processing Record 26 of Set 9 | kemijarvi
# Processing Record 27 of Set 9 | banda aceh
# Processing Record 28 of Set 9 | praia da vitoria
# Processing Record 29 of Set 9 | vardo
# Processing Record 30 of Set 9 | husavik
# Processing Record 31 of Set 9 | redmond
# Processing Record 32 of Set 9 | sobolevo
# Processing Record 33 of Set 9 | norrkoping
# Processing Record 34 of Set 9 | malakal
# Processing Record 35 of Set 9 | shahr-e babak
# Processing Record 36 of Set 9 | lasa
# Processing Record 37 of Set 9 | saskylakh
# Processing Record 38 of Set 9 | saint-augustin
# Processing Record 39 of Set 9 | aklavik
# Processing Record 40 of Set 9 | woodward
# Processing Record 41 of Set 9 | buala
# Processing Record 42 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 43 of Set 9 | nemuro
# Processing Record 44 of Set 9 | razole
# Processing Record 45 of Set 9 | san cristobal
# Processing Record 46 of Set 9 | batangafo
# Processing Record 47 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 9 | nanakuli
# Processing Record 49 of Set 9 | natal
# Processing Record 50 of Set 9 | afmadu
# City not found. Skipping...
# Processing Record 1 of Set 10 | sivas
# Processing Record 2 of Set 10 | margate
# Processing Record 3 of Set 10 | schoningen
# Processing Record 4 of Set 10 | atka
# City not found. Skipping...
# Processing Record 5 of Set 10 | baykit
# Processing Record 6 of Set 10 | camacha
# Processing Record 7 of Set 10 | verkhnyaya inta
# Processing Record 8 of Set 10 | dinar
# Processing Record 9 of Set 10 | del rio
# Processing Record 10 of Set 10 | grand junction
# Processing Record 11 of Set 10 | sagua de tanamo
# Processing Record 12 of Set 10 | williams lake
# Processing Record 13 of Set 10 | samborondon
# Processing Record 14 of Set 10 | okha
# Processing Record 15 of Set 10 | yuryev-polskiy
# Processing Record 16 of Set 10 | voyvozh
# Processing Record 17 of Set 10 | brajrajnagar
# City not found. Skipping...
# Processing Record 18 of Set 10 | himora
# City not found. Skipping...
# Processing Record 19 of Set 10 | mildura
# Processing Record 20 of Set 10 | kruisfontein
# Processing Record 21 of Set 10 | luau
# Processing Record 22 of Set 10 | zhangye
# Processing Record 23 of Set 10 | veliki trnovac
# Processing Record 24 of Set 10 | nizhnevartovsk
# Processing Record 25 of Set 10 | porto santo
# Processing Record 26 of Set 10 | bowling green
# Processing Record 27 of Set 10 | requena
# Processing Record 28 of Set 10 | oyama
# Processing Record 29 of Set 10 | sambava
# Processing Record 30 of Set 10 | kwinana
# Processing Record 31 of Set 10 | korla
# Processing Record 32 of Set 10 | potsdam
# Processing Record 33 of Set 10 | dandong
# Processing Record 34 of Set 10 | rosetta
# Processing Record 35 of Set 10 | qasigiannguit
# Processing Record 36 of Set 10 | beira
# Processing Record 37 of Set 10 | san rafael
# Processing Record 38 of Set 10 | dinguiraye
# Processing Record 39 of Set 10 | parichhatgarh
# Processing Record 40 of Set 10 | thunder bay
# Processing Record 41 of Set 10 | maarianhamina
# Processing Record 42 of Set 10 | kyrksaeterora
# Processing Record 43 of Set 10 | ballina
# Processing Record 44 of Set 10 | ambunti
# Processing Record 45 of Set 10 | kenitra
# Processing Record 46 of Set 10 | emmett
# Processing Record 47 of Set 10 | ahipara
# Processing Record 48 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 10 | mont-dore
# Processing Record 50 of Set 10 | garoua boulai
# Processing Record 1 of Set 11 | juneau
# Processing Record 2 of Set 11 | sibu
# Processing Record 3 of Set 11 | esperance
# Processing Record 4 of Set 11 | dudinka
# Processing Record 5 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 11 | voh
# Processing Record 7 of Set 11 | zhovti vody
# Processing Record 8 of Set 11 | tual
# Processing Record 9 of Set 11 | karratha
# Processing Record 10 of Set 11 | beterou
# Processing Record 11 of Set 11 | mindif
# Processing Record 12 of Set 11 | abha
# Processing Record 13 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 14 of Set 11 | kasganj
# Processing Record 15 of Set 11 | vila velha
# Processing Record 16 of Set 11 | haines junction
# Processing Record 17 of Set 11 | chota
# Processing Record 18 of Set 11 | altea
# Processing Record 19 of Set 11 | orasac
# Processing Record 20 of Set 11 | puerto narino
# Processing Record 21 of Set 11 | chowchilla
# Processing Record 22 of Set 11 | tshikapa
# Processing Record 23 of Set 11 | saint anthony
# Processing Record 24 of Set 11 | goundam
# Processing Record 25 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 26 of Set 11 | ciras
# City not found. Skipping...
# Processing Record 27 of Set 11 | suluktu
# Processing Record 28 of Set 11 | igcocolo
# Processing Record 29 of Set 11 | miquelon
# Processing Record 30 of Set 11 | itaqui
# Processing Record 31 of Set 11 | sibolga
# Processing Record 32 of Set 11 | balkanabat
# Processing Record 33 of Set 11 | ambovombe
# Processing Record 34 of Set 11 | longyearbyen
# Processing Record 35 of Set 11 | samarai
# Processing Record 36 of Set 11 | sao joao da barra
# Processing Record 37 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 11 | yenagoa
# Processing Record 39 of Set 11 | henties bay
# Processing Record 40 of Set 11 | maryborough
# Processing Record 41 of Set 11 | changping
# Processing Record 42 of Set 11 | silver city
# Processing Record 43 of Set 11 | guanay
# Processing Record 44 of Set 11 | carlos chagas
# Processing Record 45 of Set 11 | raudeberg
# Processing Record 46 of Set 11 | richards bay
# Processing Record 47 of Set 11 | pitimbu
# Processing Record 48 of Set 11 | chopinzinho
# Processing Record 49 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 11 | ciudad bolivar
# Processing Record 1 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 2 of Set 12 | roma
# Processing Record 3 of Set 12 | jacksonville beach
# Processing Record 4 of Set 12 | dickinson
# Processing Record 5 of Set 12 | dingle
# Processing Record 6 of Set 12 | canyon lake
# Processing Record 7 of Set 12 | kem
# Processing Record 8 of Set 12 | cortez
# Processing Record 9 of Set 12 | wanning
# Processing Record 10 of Set 12 | palmer
# Processing Record 11 of Set 12 | quatre cocos
# Processing Record 12 of Set 12 | prince rupert
# Processing Record 13 of Set 12 | macenta
# Processing Record 14 of Set 12 | brae
# Processing Record 15 of Set 12 | ucluelet
# Processing Record 16 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 12 | agirish
# Processing Record 18 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 19 of Set 12 | talakan
# Processing Record 20 of Set 12 | gat
# Processing Record 21 of Set 12 | patamea
# City not found. Skipping...
# Processing Record 22 of Set 12 | cardoso
# Processing Record 23 of Set 12 | batemans bay
# Processing Record 24 of Set 12 | micheweni
# Processing Record 25 of Set 12 | yulara
# Processing Record 26 of Set 12 | golkoy
# Processing Record 27 of Set 12 | tacna
# Processing Record 28 of Set 12 | cabra
# Processing Record 29 of Set 12 | valle de allende
# Processing Record 30 of Set 12 | kiunga
# Processing Record 31 of Set 12 | yar-sale
# Processing Record 32 of Set 12 | erenhot
# Processing Record 33 of Set 12 | portland
# Processing Record 34 of Set 12 | sola
# Processing Record 35 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 12 | zhuzhou
# Processing Record 37 of Set 12 | huilong
# Processing Record 38 of Set 12 | aykhal
# Processing Record 39 of Set 12 | havoysund
# Processing Record 40 of Set 12 | udachnyy
# Processing Record 41 of Set 12 | ossora
# Processing Record 42 of Set 12 | gananoque
# Processing Record 43 of Set 12 | santa rosa
# Processing Record 44 of Set 12 | jacmel
# Processing Record 45 of Set 12 | lumeje
# Processing Record 46 of Set 12 | ilovka
# Processing Record 47 of Set 12 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 48 of Set 12 | purranque
# Processing Record 49 of Set 12 | murray bridge
# Processing Record 50 of Set 12 | pahalgam
# Processing Record 1 of Set 13 | mantua
# Processing Record 2 of Set 13 | solton
# Processing Record 3 of Set 13 | kuznechnoye
# Processing Record 4 of Set 13 | soe
# Processing Record 5 of Set 13 | tomatlan
# Processing Record 6 of Set 13 | new glasgow
# Processing Record 7 of Set 13 | mandalgovi
# Processing Record 8 of Set 13 | coquimbo
# Processing Record 9 of Set 13 | salinopolis
# Processing Record 10 of Set 13 | toungoo
# City not found. Skipping...
# Processing Record 11 of Set 13 | havarna
# Processing Record 12 of Set 13 | the pas
# Processing Record 13 of Set 13 | fort nelson
# Processing Record 14 of Set 13 | ormond beach
# Processing Record 15 of Set 13 | marsaxlokk
# Processing Record 16 of Set 13 | prado
# Processing Record 17 of Set 13 | owando
# Processing Record 18 of Set 13 | doka
# Processing Record 19 of Set 13 | barra patuca
# Processing Record 20 of Set 13 | ormara
# Processing Record 21 of Set 13 | havre-saint-pierre
# Processing Record 22 of Set 13 | kieta
# Processing Record 23 of Set 13 | gull lake
# Processing Record 24 of Set 13 | amasya
# Processing Record 25 of Set 13 | kasongo-lunda
# Processing Record 26 of Set 13 | esso
# Processing Record 27 of Set 13 | chuguyevka
# Processing Record 28 of Set 13 | amapa
# Processing Record 29 of Set 13 | ozernovskiy
# Processing Record 30 of Set 13 | alta floresta
# Processing Record 31 of Set 13 | mortka
# Processing Record 32 of Set 13 | khani
# Processing Record 33 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 34 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 35 of Set 13 | aasiaat
# Processing Record 36 of Set 13 | le port
# Processing Record 37 of Set 13 | sabha
# Processing Record 38 of Set 13 | ankang
# Processing Record 39 of Set 13 | nylstroom
# City not found. Skipping...
# Processing Record 40 of Set 13 | cananeia
# Processing Record 41 of Set 13 | jiuquan
# Processing Record 42 of Set 13 | peniche
# Processing Record 43 of Set 13 | port macquarie
# Processing Record 44 of Set 13 | mormugao
# Processing Record 45 of Set 13 | kolda
# Processing Record 46 of Set 13 | lensk
# Processing Record 47 of Set 13 | egvekinot
# Processing Record 48 of Set 13 | nioro
# Processing Record 49 of Set 13 | san nicolas
# Processing Record 50 of Set 13 | kilis
# Processing Record 1 of Set 14 | petrovskaya
# Processing Record 2 of Set 14 | virginia beach
# Processing Record 3 of Set 14 | northam
# Processing Record 4 of Set 14 | staryy nadym
# Processing Record 5 of Set 14 | tadine
# Processing Record 6 of Set 14 | castilho
# Processing Record 7 of Set 14 | kayerkan
# Processing Record 8 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 9 of Set 14 | tura
# Processing Record 10 of Set 14 | dargaville
# Processing Record 11 of Set 14 | iberia
# Processing Record 12 of Set 14 | palana
# Processing Record 13 of Set 14 | nouadhibou
# Processing Record 14 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 15 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 14 | walvis bay
# Processing Record 17 of Set 14 | jumla
# Processing Record 18 of Set 14 | nuuk
# Processing Record 19 of Set 14 | lata
# Processing Record 20 of Set 14 | tres arroyos
# Processing Record 21 of Set 14 | sinjar
# Processing Record 22 of Set 14 | chissamba
# Processing Record 23 of Set 14 | mjolby
# Processing Record 24 of Set 14 | ilhabela
# Processing Record 25 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 14 | raiganj
# Processing Record 27 of Set 14 | bay roberts
# Processing Record 28 of Set 14 | uray
# Processing Record 29 of Set 14 | balaipungut
# Processing Record 30 of Set 14 | springbok
# Processing Record 31 of Set 14 | ketchikan
# Processing Record 32 of Set 14 | manta
# Processing Record 33 of Set 14 | damghan
# Processing Record 34 of Set 14 | nelson bay
# Processing Record 35 of Set 14 | zlobin
# Processing Record 36 of Set 14 | ufimskiy
# Processing Record 37 of Set 14 | cienaga
# Processing Record 38 of Set 14 | semirom
# Processing Record 39 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 14 | mezen
# Processing Record 41 of Set 14 | vega de alatorre
# Processing Record 42 of Set 14 | kirakira
# Processing Record 43 of Set 14 | uch
# Processing Record 44 of Set 14 | el retorno
# Processing Record 45 of Set 14 | hundested
# Processing Record 46 of Set 14 | beni
# Processing Record 47 of Set 14 | north bend
# Processing Record 48 of Set 14 | ayagoz
# Processing Record 49 of Set 14 | kloulklubed
# Processing Record 50 of Set 14 | san javier
# Processing Record 1 of Set 15 | dali
# Processing Record 2 of Set 15 | luganville
# Processing Record 3 of Set 15 | kudahuvadhoo
# Processing Record 4 of Set 15 | havelock
# Processing Record 5 of Set 15 | paris
# Processing Record 6 of Set 15 | lavrentiya
# Processing Record 7 of Set 15 | san miguel
# Processing Record 8 of Set 15 | tuscaloosa
# Processing Record 9 of Set 15 | taft
# Processing Record 10 of Set 15 | labrea
# Processing Record 11 of Set 15 | madimba
# Processing Record 12 of Set 15 | guaira
# Processing Record 13 of Set 15 | panji
# Processing Record 14 of Set 15 | monthey
# Processing Record 15 of Set 15 | vilyuysk
# Processing Record 16 of Set 15 | semey
# Processing Record 17 of Set 15 | kortkeros
# Processing Record 18 of Set 15 | koungou
# Processing Record 19 of Set 15 | aransas pass
# Processing Record 20 of Set 15 | shangrao
# Processing Record 21 of Set 15 | parana
# Processing Record 22 of Set 15 | severo-kurilsk
# Processing Record 23 of Set 15 | coihaique
# Processing Record 24 of Set 15 | san angelo
# Processing Record 25 of Set 15 | labytnangi
# Processing Record 26 of Set 15 | lebanon
# Processing Record 27 of Set 15 | mugur-aksy
# Processing Record 28 of Set 15 | turmalina
# Processing Record 29 of Set 15 | aitape
# Processing Record 30 of Set 15 | azad shahr
# Processing Record 31 of Set 15 | batticaloa
# Processing Record 32 of Set 15 | shimoda
# Processing Record 33 of Set 15 | horizontina
# Processing Record 34 of Set 15 | alekseyevsk
# Processing Record 35 of Set 15 | mareeba
# Processing Record 36 of Set 15 | colares
# Processing Record 37 of Set 15 | jiangyou
# Processing Record 38 of Set 15 | calatayud
# Processing Record 39 of Set 15 | skopelos
# Processing Record 40 of Set 15 | zhigansk
# Processing Record 41 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 42 of Set 15 | ahumada
# City not found. Skipping...
# Processing Record 43 of Set 15 | ovalle
# Processing Record 44 of Set 15 | niamey
# Processing Record 45 of Set 15 | tongren
# Processing Record 46 of Set 15 | vallenar
# Processing Record 47 of Set 15 | rzhev
# Processing Record 48 of Set 15 | jatai
# Processing Record 49 of Set 15 | port hedland
# Processing Record 50 of Set 15 | brandfort
# Processing Record 1 of Set 16 | rocha
# Processing Record 2 of Set 16 | nabire
# Processing Record 3 of Set 16 | matay
# Processing Record 4 of Set 16 | poum
# Processing Record 5 of Set 16 | shieli
# Processing Record 6 of Set 16 | rovaniemi
# Processing Record 7 of Set 16 | boyuibe
# Processing Record 8 of Set 16 | cao bang
# Processing Record 9 of Set 16 | kupang
# Processing Record 10 of Set 16 | merauke
# Processing Record 11 of Set 16 | wanaka
# Processing Record 12 of Set 16 | kytlym
# City not found. Skipping...
# Processing Record 13 of Set 16 | ahuatempan
# Processing Record 14 of Set 16 | tigil
# Processing Record 15 of Set 16 | rusape
# Processing Record 16 of Set 16 | joniskis
# Processing Record 17 of Set 16 | wulanhaote
# City not found. Skipping...
# Processing Record 18 of Set 16 | agadir
# Processing Record 19 of Set 16 | tarata
# Processing Record 20 of Set 16 | dongsheng
# Processing Record 21 of Set 16 | miles city
# Processing Record 22 of Set 16 | muros
# Processing Record 23 of Set 16 | mehamn
# Processing Record 24 of Set 16 | nueva guinea
# Processing Record 25 of Set 16 | sann
# Processing Record 26 of Set 16 | varva
# Processing Record 27 of Set 16 | jijiang
# Processing Record 28 of Set 16 | novyy nekouz
# Processing Record 29 of Set 16 | monte cristi
# City not found. Skipping...
# Processing Record 30 of Set 16 | zeya
# Processing Record 31 of Set 16 | kostomuksha
# Processing Record 32 of Set 16 | lawrenceburg
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_info_df = pd.DataFrame(city_data)
city_info_df.drop(columns="Date", inplace=True, axis=1)
city_info_df.to_csv('somecitydata.csv')
city_info_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Mujiayingzi  42.12  118.78     66.36        76          46       12.53
# 1           Pevek  69.70  170.31     43.72        71          58       14.41
# 2       Geraldton -28.77  114.60     62.60        67          75       11.41
# 3         Rikitea -23.12 -134.97     73.29        85           0       10.18
# 4         Mataura -46.19  168.86     55.27        54         100        3.85
# 5            Hilo  19.73 -155.09     84.20        62          90       10.29
# 6     Port Alfred -33.59   26.89     57.90        87          25        8.08
# 7  Port Elizabeth -33.92   25.57     57.20        93          75        3.36
# 8       Flin Flon  54.77 -101.86     40.17        70           5        7.56
# 9       Ilulissat  69.22  -51.10     37.40        74          81       11.41
#
#   Country Current Description
# 0      CN    scattered clouds
# 1      RU       broken clouds
# 2      AU       broken clouds
# 3      PF           clear sky
# 4      NZ     overcast clouds
# 5      US     overcast clouds
# 6      ZA    scattered clouds
# 7      ZA       broken clouds
# 8      CA           clear sky
# 9      GL       broken clouds

# %%
new_column_order=["City","Country","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_info_df = city_info_df[new_column_order]
city_info_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Mujiayingzi      CN  42.12  118.78     66.36        76          46
# 1           Pevek      RU  69.70  170.31     43.72        71          58
# 2       Geraldton      AU -28.77  114.60     62.60        67          75
# 3         Rikitea      PF -23.12 -134.97     73.29        85           0
# 4         Mataura      NZ -46.19  168.86     55.27        54         100
# 5            Hilo      US  19.73 -155.09     84.20        62          90
# 6     Port Alfred      ZA -33.59   26.89     57.90        87          25
# 7  Port Elizabeth      ZA -33.92   25.57     57.20        93          75
# 8       Flin Flon      CA  54.77 -101.86     40.17        70           5
# 9       Ilulissat      GL  69.22  -51.10     37.40        74          81
#
#    Wind Speed Current Description
# 0       12.53    scattered clouds
# 1       14.41       broken clouds
# 2       11.41       broken clouds
# 3       10.18           clear sky
# 4        3.85     overcast clouds
# 5       10.29     overcast clouds
# 6        8.08    scattered clouds
# 7        3.36       broken clouds
# 8        7.56           clear sky
# 9       11.41       broken clouds

# %%
# Export data to CSV.
city_info_df.to_csv('Weather_Database/WeatherPy_database.csv')
